# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("weather_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date/Time          8784 non-null   datetime64[ns]
#  1   Temp_C             8784 non-null   float64
#  2   Dew Point Temp_C   8784 non-null   float64
#  3   Rel Hum_%          8784 non-null   int64
#  4   Wind Speed_km/h    8784 non-null   int64
#  5   Visibility_km      8784 non-null   float64
#  6   Press_kPa          8784 non-null   float64
#  7   Weather Condition  8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df['Weather'].nunique()
# Out:
# 50

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# unique wind speed

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# how much weather is clear

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# wind speed = 4

# %%
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# Find out all the Null Values in the data.

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# Rename the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
df = df.rename(columns={'Weather':'Weather Condition'})
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather Condition'],
#       dtype='object')

# %% [markdown]
# Visibility's mean

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df[['Temp_C',	'Dew Point Temp_C',	'Rel Hum_%',	'Wind Speed_km/h',	'Visibility_km',	'Press_kPa']].var()
# Out:
# Temp_C              136.606604
# Dew Point Temp_C    118.441263
# Rel Hum_%           286.248550
# Wind Speed_km/h      75.493440
# Visibility_km       159.332259
# Press_kPa             0.712344
# dtype: float64

# %% [markdown]
# Where snow is recorded

# %%
df[df['Weather Condition'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
#  instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# What is the Mean value of each column against each 'Weather Condition ?

# %%
df['Weather Condition'] = df['Weather Condition'].str.split(',')
df = df.explode('Weather Condition')
df.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog
# 2            4.0     101.26  Freezing Drizzle
# 2            4.0     101.26               Fog
# 3            4.0     101.27  Freezing Drizzle

# %%
df.groupby('Weather Condition').describe()
# Out:
#                       Date/Time                                 \
#                           count                           mean
# Weather Condition
# Blowing Snow                 21  2012-08-22 03:22:51.428571392
# Clear                      1326  2012-06-25 18:03:12.760180992
# Cloudy                     1728  2012-07-01 16:51:29.583333376
# Drizzle                     139  2012-08-14 20:31:56.546762496
# Fog                         422  2012-07-30 10:39:14.502369536
# Freezing Drizzle             27  2012-04-29 19:15:33.333333248
# Freezing Fog                  4            2012-02-22 06:45:00
# Freezing Rain                22  2012-03-21 02:27:16.363636480
# Haze                         29  2012-04-15 00:53:47.586206976
# Heavy Rain Showers            1            2012-05-29 06:00:00
# Ice Pellets                  13  2012-11-05 10:09:13.846153728
# Mainly Clear               2106  2012-07-12 06:48:08.888888832
# Moderate Rain                 1            2012-12-10 08:00:00
# ...

# %% [markdown]
#  Show all the Records where Weather Condition is Fog.

# %%
df[df['Weather Condition'].str.contains('Fog')]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8739 2012-12-30 03:00:00    -9.1             -10.4         90
# 8740 2012-12-30 04:00:00    -9.3             -10.6         90
# 8741 2012-12-30 05:00:00    -9.1             -10.4         90
# 8742 2012-12-30 06:00:00    -9.3             -10.8         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 0                   4            8.0     101.24               Fog
# 1                   4            8.0     101.24               Fog
# ...

# %% [markdown]
#  Find all instances when 'Weather is Clear' or 'Visibility is above 40'

# %%
df[(df['Weather Condition'].str.contains('Clear')) | (df['Visibility_km']>40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 36   2012-01-02 12:00:00     1.7              -6.2         56
# 60   2012-01-03 12:00:00   -14.9             -22.6         52
# 61   2012-01-03 13:00:00   -15.1             -22.4         54
# 62   2012-01-03 14:00:00   -14.9             -22.9         50
# 63   2012-01-03 15:00:00   -14.8             -22.2         53
# ...                  ...     ...               ...        ...
# 8754 2012-12-30 18:00:00   -12.6             -16.0         76
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
# 8757 2012-12-30 21:00:00   -13.8             -16.5         80
# 8758 2012-12-30 22:00:00   -13.7             -16.3         81
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 36                 48           24.1      99.21      Mainly Clear
# 60                 20           24.1     101.34      Mainly Clear
# ...

# %% [markdown]
#  Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# or
# B. 'Visibility is above 40'

# %%
df[(df['Weather Condition'].str.contains('Clear')) & (df['Rel Hum_%']>50)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 36   2012-01-02 12:00:00     1.7              -6.2         56
# 60   2012-01-03 12:00:00   -14.9             -22.6         52
# 61   2012-01-03 13:00:00   -15.1             -22.4         54
# 63   2012-01-03 15:00:00   -14.8             -22.2         53
# 64   2012-01-03 16:00:00   -15.3             -22.9         52
# ...                  ...     ...               ...        ...
# 8754 2012-12-30 18:00:00   -12.6             -16.0         76
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
# 8757 2012-12-30 21:00:00   -13.8             -16.5         80
# 8758 2012-12-30 22:00:00   -13.7             -16.3         81
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 36                 48           24.1      99.21      Mainly Clear
# 60                 20           24.1     101.34      Mainly Clear
# ...

# %%
df[df['Visibility_km']>40]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8748 2012-12-30 12:00:00   -12.2             -15.7         75
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 106                17           48.3     100.45      Mainly Clear
# 107                22           48.3     100.41      Mainly Clear
# ...
